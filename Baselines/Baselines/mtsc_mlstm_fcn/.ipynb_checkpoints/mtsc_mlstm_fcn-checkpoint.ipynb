# %% [markdown]
# Data format conversion for MLSTM-FCN
# ===
#
#
# ---
# Input
# ---
#
# A single file contains all samples and their labels: ***L * (3 + D)***
#
#
#
# - 1st col: sample_id
# - 2nd col: timestamps
# - 3rd col: label
# - after the 4th col: mts vector with D dimensions
#
# ---
# Output
# ---
#
# Two array-like variables
#
# - X : array with shape (n_ts, d, sz)
#         Sequence data.
# - y : array with shape (n_ts, 1)
#         Target labels.

# %%
import numpy as np

# %%
rep = "./datasets/multivariate/"
ds = "ECG"
ds_train = ds + '/' + ds + "_TRAIN3"
ds_test = ds + '/' + ds + "_TEST3"

NB_CLASS = 0
MAX_TIMESTEPS = 0
MAX_NB_VARIABLES = 0

def z_normalization(mts):
    M = len(mts[0, :])
    for i in range(M):
        mts_i = mts[:, i]
        mean = np.mean(mts_i)
        std = np.std(mts_i)
        mts_i = (mts_i - mean) / std
        mts[:, i] = mts_i
    return mts

def convert_mts(rep, dataset, z_normal = False):
    global NB_CLASS, MAX_NB_VARIABLES
    
    seq = np.genfromtxt(rep + dataset, delimiter=' ', dtype=str, encoding="utf8")
    
    ids, counts = np.unique(seq[:,0], return_counts=True)
    No = ids.shape[0]
    D = seq.shape[1] - 3
    arr = np.asarray((ids, counts)).T
    Max_Seq_Len = np.max(arr[:,1].astype(np.int))
    out_X = np.zeros((No, D, Max_Seq_Len))
    out_Y = np.zeros((No, ))

    classes = np.unique(seq[:,2])
    NB_CLASS = classes.shape[0]
    MAX_NB_VARIABLES = D
    
    for idx, id in enumerate(ids):
        seq_cpy = seq[seq[:,0] == id]
        l_seq = seq_cpy.shape[0]
        out_X[idx, :, :l_seq] = np.transpose(seq_cpy[:, 3:])
        out_Y[idx] = seq_cpy[0, 2] 
        if z_normal: 
            out_X[idx, :, :l_seq] = np.transpose(z_normalization(np.transpose(out_X[idx, :, :l_seq])))
        
    return out_X, out_Y

def load_datasets(rep, ds_train, ds_test, z_normal = False):
    global MAX_TIMESTEPS
    X_train, y_train = convert_mts(rep, ds_train, z_normal)
    X_test, y_test = convert_mts(rep, ds_test, z_normal)
    if X_train.shape[-1] != X_test.shape[-1]:
        MAX_TIMESTEPS = min(X_train.shape[-1], X_test.shape[-1])
        X_train = X_train[:,:,:MAX_TIMESTEPS]
        X_test = X_test[:,:,:MAX_TIMESTEPS]
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = load_datasets(rep, ds_train, ds_test, z_normal = True)

# ''' Save the datasets '''
print("Train dataset : ", X_train.shape, y_train.shape)
print("Test dataset : ", X_test.shape, y_test.shape)
print("Train dataset metrics : ", X_train.mean(), X_train.std())
print("Test dataset : ", X_test.mean(), X_test.std())
print("Nb classes : ", len(np.unique(y_train)))

np.save(rep + ds + '/X_train.npy', X_train)
np.save(rep + ds + '/y_train.npy', y_train)
np.save(rep + ds + '/X_test.npy', X_test)
np.save(rep + ds + '/y_test.npy', y_test)

# %% [markdown]
# ---
# Build and train the Network Model
# ===

# %%
from keras.models import Model
from keras.layers import Input, Dense, LSTM, multiply, concatenate, Activation, Masking, Reshape
from keras.layers import Conv1D, BatchNormalization, GlobalAveragePooling1D, Permute, Dropout

from utils.keras_utils import train_model, evaluate_model, set_trainable
from utils.layer_utils import AttentionLSTM

TRAINABLE = True
# Out:
# Using TensorFlow backend.
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def generate_model():
    ip = Input(shape=(MAX_NB_VARIABLES, MAX_TIMESTEPS))

    x = Masking()(ip)
    x = LSTM(128)(x)
    x = Dropout(0.8)(x)

    y = Permute((2, 1))(ip)
    y = Conv1D(128, 8, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = squeeze_excite_block(y)

    y = Conv1D(256, 5, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = squeeze_excite_block(y)

    y = Conv1D(128, 3, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)

    y = GlobalAveragePooling1D()(y)

    x = concatenate([x, y])

    out = Dense(NB_CLASS, activation='softmax')(x)

    model = Model(ip, out)
    model.summary()

    # add load model code here to fine-tune

    return model


def generate_model_2():
    ip = Input(shape=(MAX_NB_VARIABLES, MAX_TIMESTEPS))
    # stride = 10

    # x = Permute((2, 1))(ip)
    # x = Conv1D(MAX_NB_VARIABLES // stride, 8, strides=stride, padding='same', activation='relu', use_bias=False,
    #            kernel_initializer='he_uniform')(x)  # (None, variables / stride, timesteps)
    # x = Permute((2, 1))(x)

    #ip1 = K.reshape(ip,shape=(MAX_TIMESTEPS,MAX_NB_VARIABLES))
    #x = Permute((2, 1))(ip)
    x = Masking()(ip)
    x = AttentionLSTM(128)(x)
    x = Dropout(0.8)(x)

    y = Permute((2, 1))(ip)
    y = Conv1D(128, 8, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = squeeze_excite_block(y)

    y = Conv1D(256, 5, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = squeeze_excite_block(y)

    y = Conv1D(128, 3, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)

    y = GlobalAveragePooling1D()(y)

    x = concatenate([x, y])

    out = Dense(NB_CLASS, activation='softmax')(x)

    model = Model(ip, out)
    model.summary()

    # add load model code here to fine-tune

    return model

def generate_model_3():
    ip = Input(shape=(MAX_NB_VARIABLES, MAX_TIMESTEPS))

    x = Masking()(ip)
    x = LSTM(8)(x)
    x = Dropout(0.8)(x)

    y = Permute((2, 1))(ip)
    y = Conv1D(128, 8, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    #y = squeeze_excite_block(y)

    y = Conv1D(256, 5, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    #y = squeeze_excite_block(y)

    y = Conv1D(128, 3, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)

    y = GlobalAveragePooling1D()(y)

    x = concatenate([x, y])

    out = Dense(NB_CLASS, activation='softmax')(x)

    model = Model(ip, out)
    model.summary()

    # add load model code here to fine-tune

    return model


def generate_model_4():
    ip = Input(shape=(MAX_NB_VARIABLES, MAX_TIMESTEPS))
    # stride = 3
    #
    # x = Permute((2, 1))(ip)
    # x = Conv1D(MAX_NB_VARIABLES // stride, 8, strides=stride, padding='same', activation='relu', use_bias=False,
    #            kernel_initializer='he_uniform')(x)  # (None, variables / stride, timesteps)
    # x = Permute((2, 1))(x)

    x = Masking()(ip)
    x = AttentionLSTM(8)(x)
    x = Dropout(0.8)(x)

    y = Permute((2, 1))(ip)
    y = Conv1D(128, 8, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    #y = squeeze_excite_block(y)

    y = Conv1D(256, 5, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    #y = squeeze_excite_block(y)

    y = Conv1D(128, 3, padding='same', kernel_initializer='he_uniform')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)

    y = GlobalAveragePooling1D()(y)

    x = concatenate([x, y])

    out = Dense(NB_CLASS, activation='softmax')(x)

    model = Model(ip, out)
    model.summary()

    # add load model code here to fine-tune

    return model

def squeeze_excite_block(input):
    ''' Create a squeeze-excite block
    Args:
        input: input tensor
        filters: number of output filters
        k: width factor

    Returns: a keras tensor
    '''
    filters = input._keras_shape[-1] # channel_axis = -1 for TF

    se = GlobalAveragePooling1D()(input)
    se = Reshape((1, filters))(se)
    se = Dense(filters // 16,  activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)
    se = multiply([input, se])
    return se

# %%
model = generate_model_2()

DATASET_INDEX = rep + ds + '/'

train_model(model, DATASET_INDEX, dataset_prefix=ds+'_', epochs=1000, batch_size=128)

evaluate_model(model, DATASET_INDEX, dataset_prefix=ds+'_', batch_size=128)
# Out:
# WARNING:tensorflow:From /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:3794: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 2, 147)       0
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 147, 2)       0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 147, 128)     2176        permute_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 128)     512         conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 128)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           activation_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 128)       0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 8)         1024        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 128)       1024        dense_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 147, 128)     0           activation_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 147, 256)     164096      multiply_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 256)     1024        conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 256)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 256)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 256)       0           global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 16)        4096        reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 256)       4096        dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 147, 256)     0           activation_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 147, 128)     98432       multiply_2[0][0]
# __________________________________________________________________________________________________
# masking_1 (Masking)             (None, 2, 147)       0           input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 147, 128)     512         conv1d_3[0][0]
# __________________________________________________________________________________________________
# attention_lstm_1 (AttentionLSTM (None, 128)          252032      masking_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 147, 128)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           attention_lstm_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 128)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256)          0           dropout_1[0][0]
#                                                                  global_average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            514         concatenate_1[0][0]
# ==================================================================================================
# Total params: 529,538
# Trainable params: 528,514
# Non-trainable params: 1,024
# __________________________________________________________________________________________________
# Finished processing train dataset..
# Finished loading test dataset..
#
# Number of train samples :  100 Number of test samples :  100
# Number of classes :  2
# Sequence length :  147
# X_train.shape is  (100, 2, 147)
# X_test.shape is  (100, 2, 147)
# Class weights :  [1.47058824 0.75757576]
# WARNING:tensorflow:From /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 100 samples, validate on 100 samples
# Epoch 1/1000
#  - 9s - loss: 0.7030 - accuracy: 0.5500 - val_loss: 0.5972 - val_accuracy: 0.6700
# Epoch 2/1000
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/keras/callbacks/callbacks.py:1042: RuntimeWarning: Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_accuracy,loss,accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
#  - 1s - loss: 0.5507 - accuracy: 0.7200 - val_loss: 0.5548 - val_accuracy: 0.6700
# Epoch 3/1000
#  - 1s - loss: 0.4515 - accuracy: 0.7800 - val_loss: 0.5419 - val_accuracy: 0.6700
# Epoch 4/1000
#  - 1s - loss: 0.4219 - accuracy: 0.8300 - val_loss: 0.5344 - val_accuracy: 0.6700
# Epoch 5/1000
#  - 1s - loss: 0.3947 - accuracy: 0.8200 - val_loss: 0.5252 - val_accuracy: 0.6800
# Epoch 6/1000
#  - 1s - loss: 0.3371 - accuracy: 0.8600 - val_loss: 0.5156 - val_accuracy: 0.7100
# Epoch 7/1000
#  - 1s - loss: 0.3430 - accuracy: 0.8600 - val_loss: 0.5062 - val_accuracy: 0.7300
# Epoch 8/1000
#  - 1s - loss: 0.3182 - accuracy: 0.8800 - val_loss: 0.4954 - val_accuracy: 0.7500
# Epoch 9/1000
#  - 1s - loss: 0.2805 - accuracy: 0.8900 - val_loss: 0.4828 - val_accuracy: 0.7400
# Epoch 10/1000
#  - 1s - loss: 0.2600 - accuracy: 0.9000 - val_loss: 0.4719 - val_accuracy: 0.7400
# Epoch 11/1000
#  - 1s - loss: 0.2986 - accuracy: 0.8600 - val_loss: 0.4620 - val_accuracy: 0.7500
# Epoch 12/1000
#  - 1s - loss: 0.2608 - accuracy: 0.8700 - val_loss: 0.4546 - val_accuracy: 0.7700
# Epoch 13/1000
#  - 1s - loss: 0.2594 - accuracy: 0.9100 - val_loss: 0.4466 - val_accuracy: 0.7800
# Epoch 14/1000
#  - 1s - loss: 0.2552 - accuracy: 0.9000 - val_loss: 0.4396 - val_accuracy: 0.7800
# Epoch 15/1000
#  - 1s - loss: 0.2197 - accuracy: 0.9200 - val_loss: 0.4322 - val_accuracy: 0.7900
# Epoch 16/1000
#  - 1s - loss: 0.2250 - accuracy: 0.9300 - val_loss: 0.4250 - val_accuracy: 0.7900
# Epoch 17/1000
#  - 1s - loss: 0.2148 - accuracy: 0.9400 - val_loss: 0.4179 - val_accuracy: 0.8000
# Epoch 18/1000
#  - 1s - loss: 0.1967 - accuracy: 0.9300 - val_loss: 0.4098 - val_accuracy: 0.8200
# Epoch 19/1000
#  - 1s - loss: 0.1564 - accuracy: 0.9500 - val_loss: 0.4027 - val_accuracy: 0.8000
# Epoch 20/1000
#  - 1s - loss: 0.1651 - accuracy: 0.9600 - val_loss: 0.3966 - val_accuracy: 0.8200
# Epoch 21/1000
#  - 1s - loss: 0.1704 - accuracy: 0.9600 - val_loss: 0.3914 - val_accuracy: 0.8400
# Epoch 22/1000
#  - 1s - loss: 0.1316 - accuracy: 0.9700 - val_loss: 0.3866 - val_accuracy: 0.8500
# Epoch 23/1000
#  - 1s - loss: 0.1403 - accuracy: 0.9700 - val_loss: 0.3827 - val_accuracy: 0.8500
# Epoch 24/1000
#  - 1s - loss: 0.1371 - accuracy: 0.9500 - val_loss: 0.3780 - val_accuracy: 0.8500
# Epoch 25/1000
#  - 1s - loss: 0.1095 - accuracy: 0.9700 - val_loss: 0.3731 - val_accuracy: 0.8500
# Epoch 26/1000
#  - 1s - loss: 0.1160 - accuracy: 0.9700 - val_loss: 0.3667 - val_accuracy: 0.8500
# Epoch 27/1000
#  - 1s - loss: 0.1065 - accuracy: 0.9700 - val_loss: 0.3603 - val_accuracy: 0.8600
# Epoch 28/1000
#  - 1s - loss: 0.0826 - accuracy: 0.9700 - val_loss: 0.3547 - val_accuracy: 0.8700
# Epoch 29/1000
#  - 1s - loss: 0.0834 - accuracy: 0.9700 - val_loss: 0.3505 - val_accuracy: 0.8600
# Epoch 30/1000
#  - 1s - loss: 0.0901 - accuracy: 0.9700 - val_loss: 0.3479 - val_accuracy: 0.8600
# Epoch 31/1000
#  - 1s - loss: 0.0787 - accuracy: 0.9800 - val_loss: 0.3461 - val_accuracy: 0.8600
# Epoch 32/1000
#  - 1s - loss: 0.0697 - accuracy: 0.9700 - val_loss: 0.3455 - val_accuracy: 0.8600
# Epoch 33/1000
#  - 1s - loss: 0.0829 - accuracy: 0.9800 - val_loss: 0.3460 - val_accuracy: 0.8700
# Epoch 34/1000
#  - 1s - loss: 0.0600 - accuracy: 0.9800 - val_loss: 0.3480 - val_accuracy: 0.8800
# Epoch 35/1000
#  - 1s - loss: 0.0613 - accuracy: 0.9800 - val_loss: 0.3485 - val_accuracy: 0.8700
# Epoch 36/1000
#  - 1s - loss: 0.0536 - accuracy: 0.9800 - val_loss: 0.3474 - val_accuracy: 0.8600
# Epoch 37/1000
#  - 1s - loss: 0.0472 - accuracy: 0.9900 - val_loss: 0.3458 - val_accuracy: 0.8500
# Epoch 38/1000
#  - 1s - loss: 0.0437 - accuracy: 0.9900 - val_loss: 0.3440 - val_accuracy: 0.8600
# Epoch 39/1000
#  - 1s - loss: 0.0381 - accuracy: 0.9900 - val_loss: 0.3444 - val_accuracy: 0.8600
# Epoch 40/1000
#  - 1s - loss: 0.0322 - accuracy: 0.9900 - val_loss: 0.3449 - val_accuracy: 0.8600
# Epoch 41/1000
#  - 1s - loss: 0.0478 - accuracy: 0.9900 - val_loss: 0.3432 - val_accuracy: 0.8600
# Epoch 42/1000
#  - 1s - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.3420 - val_accuracy: 0.8600
# Epoch 43/1000
#  - 1s - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.3417 - val_accuracy: 0.8600
# Epoch 44/1000
#  - 1s - loss: 0.0346 - accuracy: 0.9900 - val_loss: 0.3398 - val_accuracy: 0.8600
# Epoch 45/1000
#  - 1s - loss: 0.0249 - accuracy: 0.9900 - val_loss: 0.3387 - val_accuracy: 0.8600
# Epoch 46/1000
#  - 1s - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.8600
# Epoch 47/1000
#  - 1s - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.3396 - val_accuracy: 0.8600
# Epoch 48/1000
#  - 1s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.3418 - val_accuracy: 0.8600
# Epoch 49/1000
#  - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.3432 - val_accuracy: 0.8700
# Epoch 50/1000
#  - 1s - loss: 0.0177 - accuracy: 0.9900 - val_loss: 0.3437 - val_accuracy: 0.8700
# Epoch 51/1000
#  - 1s - loss: 0.0215 - accuracy: 0.9900 - val_loss: 0.3445 - val_accuracy: 0.8500
# Epoch 52/1000
#  - 1s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.3443 - val_accuracy: 0.8500
# Epoch 53/1000
#  - 1s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.3448 - val_accuracy: 0.8500
# Epoch 54/1000
#  - 1s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.3450 - val_accuracy: 0.8600
# Epoch 55/1000
#  - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.3470 - val_accuracy: 0.8700
# Epoch 56/1000
#  - 1s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.3468 - val_accuracy: 0.8700
# Epoch 57/1000
#  - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.3463 - val_accuracy: 0.8900
# Epoch 58/1000
#  - 1s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.3454 - val_accuracy: 0.8800
# Epoch 59/1000
#  - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.3446 - val_accuracy: 0.8800
# Epoch 60/1000
#  - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.3434 - val_accuracy: 0.8700
# Epoch 61/1000
#  - 1s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.3444 - val_accuracy: 0.8700
# Epoch 62/1000
#  - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3458 - val_accuracy: 0.8700
# Epoch 63/1000
#  - 1s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.3474 - val_accuracy: 0.8700
# Epoch 64/1000
#  - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3493 - val_accuracy: 0.8700
# Epoch 65/1000
#  - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3510 - val_accuracy: 0.8700
# Epoch 66/1000
#  - 2s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3542 - val_accuracy: 0.8700
# Epoch 67/1000
#  - 2s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.3578 - val_accuracy: 0.8600
# Epoch 68/1000
#  - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3617 - val_accuracy: 0.8700
# Epoch 69/1000
#  - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3642 - val_accuracy: 0.8700
# Epoch 70/1000
#  - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3655 - val_accuracy: 0.8700
# Epoch 71/1000
#  - 1s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3668 - val_accuracy: 0.8700
# Epoch 72/1000
#  - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3681 - val_accuracy: 0.8700
# Epoch 73/1000
#  - 1s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.3685 - val_accuracy: 0.8700
# Epoch 74/1000
#  - 1s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.3658 - val_accuracy: 0.8700
# Epoch 75/1000
#  - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3610 - val_accuracy: 0.8700
# Epoch 76/1000
#  - 1s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3574 - val_accuracy: 0.8700
# Epoch 77/1000
#  - 1s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3543 - val_accuracy: 0.8700
# Epoch 78/1000
#  - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3520 - val_accuracy: 0.8600
# Epoch 79/1000
#  - 1s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3505 - val_accuracy: 0.8600
# Epoch 80/1000
#  - 1s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3501 - val_accuracy: 0.8600
# Epoch 81/1000
#  - 1s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3501 - val_accuracy: 0.8600
# Epoch 82/1000
#  - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3505 - val_accuracy: 0.8600
# Epoch 83/1000
#  - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.8700
# Epoch 84/1000
#  - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3532 - val_accuracy: 0.8700
# Epoch 85/1000
#  - 1s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3562 - val_accuracy: 0.8900
# Epoch 86/1000
#  - 1s - loss: 8.7420e-04 - accuracy: 1.0000 - val_loss: 0.3596 - val_accuracy: 0.8900
# Epoch 87/1000
#  - 1s - loss: 7.5714e-04 - accuracy: 1.0000 - val_loss: 0.3622 - val_accuracy: 0.8800
# Epoch 88/1000
#  - 1s - loss: 9.1411e-04 - accuracy: 1.0000 - val_loss: 0.3648 - val_accuracy: 0.8800
# Epoch 89/1000
#  - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3666 - val_accuracy: 0.8800
# Epoch 90/1000
#  - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3663 - val_accuracy: 0.8900
# Epoch 91/1000
#  - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3661 - val_accuracy: 0.8900
# Epoch 92/1000
#  - 1s - loss: 9.0841e-04 - accuracy: 1.0000 - val_loss: 0.3656 - val_accuracy: 0.8700
# Epoch 93/1000
#  - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3649 - val_accuracy: 0.8700
# Epoch 94/1000
#  - 1s - loss: 7.0263e-04 - accuracy: 1.0000 - val_loss: 0.3654 - val_accuracy: 0.8500
# Epoch 95/1000
#  - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3661 - val_accuracy: 0.8500
# Epoch 96/1000
#  - 1s - loss: 9.2497e-04 - accuracy: 1.0000 - val_loss: 0.3664 - val_accuracy: 0.8400
# Epoch 97/1000
#  - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3663 - val_accuracy: 0.8400
# Epoch 98/1000
#  - 1s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3658 - val_accuracy: 0.8500
# Epoch 99/1000
#  - 1s - loss: 8.6783e-04 - accuracy: 1.0000 - val_loss: 0.3655 - val_accuracy: 0.8500
# Epoch 100/1000
#  - 1s - loss: 8.5505e-04 - accuracy: 1.0000 - val_loss: 0.3652 - val_accuracy: 0.8600
# Epoch 101/1000
#  - 1s - loss: 9.8035e-04 - accuracy: 1.0000 - val_loss: 0.3654 - val_accuracy: 0.8600
# Epoch 102/1000
#  - 1s - loss: 9.0022e-04 - accuracy: 1.0000 - val_loss: 0.3658 - val_accuracy: 0.8600
# Epoch 103/1000
#  - 1s - loss: 6.9080e-04 - accuracy: 1.0000 - val_loss: 0.3660 - val_accuracy: 0.8600
# Epoch 104/1000
#  - 1s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3658 - val_accuracy: 0.8600
# Epoch 105/1000
#  - 1s - loss: 7.4385e-04 - accuracy: 1.0000 - val_loss: 0.3659 - val_accuracy: 0.8600
# Epoch 106/1000
#  - 1s - loss: 7.3008e-04 - accuracy: 1.0000 - val_loss: 0.3664 - val_accuracy: 0.8700
# Epoch 107/1000
#  - 1s - loss: 7.0760e-04 - accuracy: 1.0000 - val_loss: 0.3669 - val_accuracy: 0.8700
# Epoch 108/1000
#  - 1s - loss: 4.9656e-04 - accuracy: 1.0000 - val_loss: 0.3674 - val_accuracy: 0.8700
# Epoch 109/1000
#  - 1s - loss: 6.4344e-04 - accuracy: 1.0000 - val_loss: 0.3679 - val_accuracy: 0.8700
# Epoch 110/1000
#  - 1s - loss: 5.9407e-04 - accuracy: 1.0000 - val_loss: 0.3687 - val_accuracy: 0.8600
# Epoch 111/1000
#  - 1s - loss: 7.6089e-04 - accuracy: 1.0000 - val_loss: 0.3697 - val_accuracy: 0.8600
# Epoch 112/1000
#  - 1s - loss: 5.7708e-04 - accuracy: 1.0000 - val_loss: 0.3721 - val_accuracy: 0.8600
# Epoch 113/1000
#  - 1s - loss: 8.5096e-04 - accuracy: 1.0000 - val_loss: 0.3753 - val_accuracy: 0.8800
# Epoch 114/1000
#  - 1s - loss: 7.1858e-04 - accuracy: 1.0000 - val_loss: 0.3790 - val_accuracy: 0.8800
# Epoch 115/1000
#  - 1s - loss: 7.5871e-04 - accuracy: 1.0000 - val_loss: 0.3831 - val_accuracy: 0.8800
# Epoch 116/1000
#  - 1s - loss: 3.2646e-04 - accuracy: 1.0000 - val_loss: 0.3872 - val_accuracy: 0.8800
# Epoch 117/1000
#  - 1s - loss: 5.3864e-04 - accuracy: 1.0000 - val_loss: 0.3900 - val_accuracy: 0.8800
# Epoch 118/1000
#  - 1s - loss: 6.5577e-04 - accuracy: 1.0000 - val_loss: 0.3908 - val_accuracy: 0.8800
# Epoch 119/1000
#  - 1s - loss: 6.8710e-04 - accuracy: 1.0000 - val_loss: 0.3908 - val_accuracy: 0.8800
# Epoch 120/1000
#  - 1s - loss: 5.6894e-04 - accuracy: 1.0000 - val_loss: 0.3906 - val_accuracy: 0.8800
# Epoch 121/1000
#  - 1s - loss: 4.3493e-04 - accuracy: 1.0000 - val_loss: 0.3903 - val_accuracy: 0.8800
# Epoch 122/1000
#  - 1s - loss: 6.8133e-04 - accuracy: 1.0000 - val_loss: 0.3897 - val_accuracy: 0.8800
# Epoch 123/1000
#  - 1s - loss: 7.4391e-04 - accuracy: 1.0000 - val_loss: 0.3879 - val_accuracy: 0.8800
# Epoch 124/1000
#  - 1s - loss: 4.9029e-04 - accuracy: 1.0000 - val_loss: 0.3868 - val_accuracy: 0.8700
# Epoch 125/1000
#  - 1s - loss: 4.4083e-04 - accuracy: 1.0000 - val_loss: 0.3860 - val_accuracy: 0.8700
# Epoch 126/1000
#  - 1s - loss: 5.0097e-04 - accuracy: 1.0000 - val_loss: 0.3859 - val_accuracy: 0.8700
# Epoch 127/1000
#  - 1s - loss: 4.5775e-04 - accuracy: 1.0000 - val_loss: 0.3863 - val_accuracy: 0.8700
# Epoch 128/1000
#  - 1s - loss: 3.9782e-04 - accuracy: 1.0000 - val_loss: 0.3871 - val_accuracy: 0.8600
# Epoch 129/1000
#  - 1s - loss: 4.2861e-04 - accuracy: 1.0000 - val_loss: 0.3882 - val_accuracy: 0.8600
# Epoch 130/1000
#  - 1s - loss: 3.9711e-04 - accuracy: 1.0000 - val_loss: 0.3896 - val_accuracy: 0.8600
# Epoch 131/1000
#  - 1s - loss: 4.0843e-04 - accuracy: 1.0000 - val_loss: 0.3912 - val_accuracy: 0.8600
# Epoch 132/1000
#  - 1s - loss: 4.2507e-04 - accuracy: 1.0000 - val_loss: 0.3929 - val_accuracy: 0.8600
# Epoch 133/1000
#  - 1s - loss: 5.9171e-04 - accuracy: 1.0000 - val_loss: 0.3947 - val_accuracy: 0.8700
# Epoch 134/1000
#  - 1s - loss: 5.2712e-04 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.8700
# Epoch 135/1000
#  - 1s - loss: 5.2872e-04 - accuracy: 1.0000 - val_loss: 0.3980 - val_accuracy: 0.8700
# Epoch 136/1000
#  - 1s - loss: 3.0551e-04 - accuracy: 1.0000 - val_loss: 0.3996 - val_accuracy: 0.8700
# Epoch 137/1000
#  - 1s - loss: 5.2280e-04 - accuracy: 1.0000 - val_loss: 0.4012 - val_accuracy: 0.8700
# Epoch 138/1000
#  - 1s - loss: 5.3985e-04 - accuracy: 1.0000 - val_loss: 0.4040 - val_accuracy: 0.8700
# Epoch 139/1000
#  - 1s - loss: 3.1752e-04 - accuracy: 1.0000 - val_loss: 0.4072 - val_accuracy: 0.8800
# Epoch 140/1000
#  - 1s - loss: 2.8635e-04 - accuracy: 1.0000 - val_loss: 0.4103 - val_accuracy: 0.8800
# Epoch 141/1000
#  - 1s - loss: 5.2989e-04 - accuracy: 1.0000 - val_loss: 0.4140 - val_accuracy: 0.8800
# Epoch 142/1000
#  - 1s - loss: 3.4435e-04 - accuracy: 1.0000 - val_loss: 0.4178 - val_accuracy: 0.8800
# Epoch 143/1000
#  - 1s - loss: 3.6068e-04 - accuracy: 1.0000 - val_loss: 0.4212 - val_accuracy: 0.8800
# Epoch 144/1000
#  - 1s - loss: 4.2261e-04 - accuracy: 1.0000 - val_loss: 0.4245 - val_accuracy: 0.8800
# Epoch 145/1000
#  - 1s - loss: 3.8921e-04 - accuracy: 1.0000 - val_loss: 0.4271 - val_accuracy: 0.8800
# Epoch 146/1000
#  - 1s - loss: 3.1806e-04 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.8800
# Epoch 147/1000
#  - 1s - loss: 6.7751e-04 - accuracy: 1.0000 - val_loss: 0.4298 - val_accuracy: 0.8800
# Epoch 148/1000
#  - 1s - loss: 2.9184e-04 - accuracy: 1.0000 - val_loss: 0.4296 - val_accuracy: 0.8800
# Epoch 149/1000
#  - 1s - loss: 3.7500e-04 - accuracy: 1.0000 - val_loss: 0.4292 - val_accuracy: 0.8800
# Epoch 150/1000
#  - 1s - loss: 2.5577e-04 - accuracy: 1.0000 - val_loss: 0.4286 - val_accuracy: 0.8800
# Epoch 151/1000
#  - 1s - loss: 5.3983e-04 - accuracy: 1.0000 - val_loss: 0.4252 - val_accuracy: 0.8800
# Epoch 152/1000
#  - 1s - loss: 2.9712e-04 - accuracy: 1.0000 - val_loss: 0.4229 - val_accuracy: 0.8800
# Epoch 153/1000
#  - 1s - loss: 2.5638e-04 - accuracy: 1.0000 - val_loss: 0.4216 - val_accuracy: 0.8700
# Epoch 154/1000
#  - 1s - loss: 4.4356e-04 - accuracy: 1.0000 - val_loss: 0.4202 - val_accuracy: 0.8600
# Epoch 155/1000
#  - 1s - loss: 3.4201e-04 - accuracy: 1.0000 - val_loss: 0.4196 - val_accuracy: 0.8600
# Epoch 156/1000
#  - 1s - loss: 2.6441e-04 - accuracy: 1.0000 - val_loss: 0.4199 - val_accuracy: 0.8600
# Epoch 157/1000
#  - 1s - loss: 3.5387e-04 - accuracy: 1.0000 - val_loss: 0.4211 - val_accuracy: 0.8500
# Epoch 158/1000
#  - 1s - loss: 3.9976e-04 - accuracy: 1.0000 - val_loss: 0.4224 - val_accuracy: 0.8500
# Epoch 159/1000
#  - 1s - loss: 4.2237e-04 - accuracy: 1.0000 - val_loss: 0.4236 - val_accuracy: 0.8500
# Epoch 160/1000
#  - 1s - loss: 3.9836e-04 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.8500
# Epoch 161/1000
#  - 1s - loss: 3.8023e-04 - accuracy: 1.0000 - val_loss: 0.4265 - val_accuracy: 0.8500
# Epoch 162/1000
#  - 1s - loss: 2.8594e-04 - accuracy: 1.0000 - val_loss: 0.4279 - val_accuracy: 0.8600
# Epoch 163/1000
#  - 1s - loss: 2.9121e-04 - accuracy: 1.0000 - val_loss: 0.4298 - val_accuracy: 0.8600
# Epoch 164/1000
#  - 1s - loss: 2.7527e-04 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 0.8600
# Epoch 165/1000
#  - 1s - loss: 2.5634e-04 - accuracy: 1.0000 - val_loss: 0.4341 - val_accuracy: 0.8600
# Epoch 166/1000
#  - 1s - loss: 4.0431e-04 - accuracy: 1.0000 - val_loss: 0.4367 - val_accuracy: 0.8600
# Epoch 167/1000
#  - 1s - loss: 2.8248e-04 - accuracy: 1.0000 - val_loss: 0.4394 - val_accuracy: 0.8600
# Epoch 168/1000
#  - 1s - loss: 3.9707e-04 - accuracy: 1.0000 - val_loss: 0.4419 - val_accuracy: 0.8600
# Epoch 169/1000
#  - 1s - loss: 2.7963e-04 - accuracy: 1.0000 - val_loss: 0.4447 - val_accuracy: 0.8600
# Epoch 170/1000
#  - 1s - loss: 2.9623e-04 - accuracy: 1.0000 - val_loss: 0.4470 - val_accuracy: 0.8600
# Epoch 171/1000
#  - 1s - loss: 2.7037e-04 - accuracy: 1.0000 - val_loss: 0.4491 - val_accuracy: 0.8600
# Epoch 172/1000
#  - 1s - loss: 2.5718e-04 - accuracy: 1.0000 - val_loss: 0.4511 - val_accuracy: 0.8700
# Epoch 173/1000
#  - 1s - loss: 2.6816e-04 - accuracy: 1.0000 - val_loss: 0.4523 - val_accuracy: 0.8700
# Epoch 174/1000
#  - 1s - loss: 2.9926e-04 - accuracy: 1.0000 - val_loss: 0.4532 - val_accuracy: 0.8700
# Epoch 175/1000
#  - 1s - loss: 2.1823e-04 - accuracy: 1.0000 - val_loss: 0.4541 - val_accuracy: 0.8700
# Epoch 176/1000
#  - 1s - loss: 3.0495e-04 - accuracy: 1.0000 - val_loss: 0.4554 - val_accuracy: 0.8700
# Epoch 177/1000
#  - 1s - loss: 1.9837e-04 - accuracy: 1.0000 - val_loss: 0.4567 - val_accuracy: 0.8600
# Epoch 178/1000
#  - 1s - loss: 2.7336e-04 - accuracy: 1.0000 - val_loss: 0.4580 - val_accuracy: 0.8600
# Epoch 179/1000
#  - 1s - loss: 2.4023e-04 - accuracy: 1.0000 - val_loss: 0.4595 - val_accuracy: 0.8600
# Epoch 180/1000
#  - 1s - loss: 2.1657e-04 - accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 0.8600
# Epoch 181/1000
#  - 1s - loss: 2.3458e-04 - accuracy: 1.0000 - val_loss: 0.4625 - val_accuracy: 0.8600
# Epoch 182/1000
#  - 1s - loss: 2.2903e-04 - accuracy: 1.0000 - val_loss: 0.4639 - val_accuracy: 0.8600
# Epoch 183/1000
#  - 1s - loss: 2.2582e-04 - accuracy: 1.0000 - val_loss: 0.4654 - val_accuracy: 0.8600
# Epoch 184/1000
#  - 1s - loss: 2.5293e-04 - accuracy: 1.0000 - val_loss: 0.4666 - val_accuracy: 0.8600
# Epoch 185/1000
#  - 1s - loss: 2.1271e-04 - accuracy: 1.0000 - val_loss: 0.4677 - val_accuracy: 0.8600
# Epoch 186/1000
#  - 1s - loss: 2.3108e-04 - accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.8600
# Epoch 187/1000
#  - 1s - loss: 2.3105e-04 - accuracy: 1.0000 - val_loss: 0.4700 - val_accuracy: 0.8600
# Epoch 188/1000
#  - 1s - loss: 1.8547e-04 - accuracy: 1.0000 - val_loss: 0.4712 - val_accuracy: 0.8600
# Epoch 189/1000
#  - 1s - loss: 2.8993e-04 - accuracy: 1.0000 - val_loss: 0.4725 - val_accuracy: 0.8600
# Epoch 190/1000
#  - 1s - loss: 2.0881e-04 - accuracy: 1.0000 - val_loss: 0.4739 - val_accuracy: 0.8600
# Epoch 191/1000
#  - 1s - loss: 2.0054e-04 - accuracy: 1.0000 - val_loss: 0.4753 - val_accuracy: 0.8600
# Epoch 192/1000
#  - 1s - loss: 2.4534e-04 - accuracy: 1.0000 - val_loss: 0.4766 - val_accuracy: 0.8600
# Epoch 193/1000
#  - 1s - loss: 1.7567e-04 - accuracy: 1.0000 - val_loss: 0.4779 - val_accuracy: 0.8600
# Epoch 194/1000
#  - 1s - loss: 2.3406e-04 - accuracy: 1.0000 - val_loss: 0.4792 - val_accuracy: 0.8600
# Epoch 195/1000
#  - 1s - loss: 2.2862e-04 - accuracy: 1.0000 - val_loss: 0.4805 - val_accuracy: 0.8600
# Epoch 196/1000
#  - 1s - loss: 1.9834e-04 - accuracy: 1.0000 - val_loss: 0.4817 - val_accuracy: 0.8600
# Epoch 197/1000
#  - 1s - loss: 1.9855e-04 - accuracy: 1.0000 - val_loss: 0.4829 - val_accuracy: 0.8700
# Epoch 198/1000
#  - 1s - loss: 2.5380e-04 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8700
# Epoch 199/1000
#  - 1s - loss: 1.8200e-04 - accuracy: 1.0000 - val_loss: 0.4856 - val_accuracy: 0.8700
# Epoch 200/1000
#  - 1s - loss: 1.7360e-04 - accuracy: 1.0000 - val_loss: 0.4872 - val_accuracy: 0.8700
# Epoch 201/1000
#  - 1s - loss: 1.6793e-04 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.8700
# Epoch 202/1000
#  - 1s - loss: 2.5928e-04 - accuracy: 1.0000 - val_loss: 0.4908 - val_accuracy: 0.8700
# Epoch 203/1000
#  - 1s - loss: 1.9280e-04 - accuracy: 1.0000 - val_loss: 0.4926 - val_accuracy: 0.8600
# Epoch 204/1000
#  - 1s - loss: 2.4841e-04 - accuracy: 1.0000 - val_loss: 0.4945 - val_accuracy: 0.8600
# Epoch 205/1000
#  - 1s - loss: 1.9968e-04 - accuracy: 1.0000 - val_loss: 0.4963 - val_accuracy: 0.8600
# Epoch 206/1000
#  - 1s - loss: 2.2435e-04 - accuracy: 1.0000 - val_loss: 0.4983 - val_accuracy: 0.8600
# Epoch 207/1000
#  - 1s - loss: 1.7538e-04 - accuracy: 1.0000 - val_loss: 0.5004 - val_accuracy: 0.8600
# Epoch 208/1000
#  - 1s - loss: 2.3806e-04 - accuracy: 1.0000 - val_loss: 0.5023 - val_accuracy: 0.8600
# Epoch 209/1000
#  - 1s - loss: 1.9932e-04 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.8600
# Epoch 210/1000
#  - 1s - loss: 2.9766e-04 - accuracy: 1.0000 - val_loss: 0.5057 - val_accuracy: 0.8600
# Epoch 211/1000
#  - 1s - loss: 1.5111e-04 - accuracy: 1.0000 - val_loss: 0.5072 - val_accuracy: 0.8600
# Epoch 212/1000
#  - 1s - loss: 1.2716e-04 - accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.8600
# Epoch 213/1000
#  - 1s - loss: 1.9920e-04 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.8600
# Epoch 214/1000
#  - 1s - loss: 1.6678e-04 - accuracy: 1.0000 - val_loss: 0.5119 - val_accuracy: 0.8600
# Epoch 215/1000
#  - 1s - loss: 2.7834e-04 - accuracy: 1.0000 - val_loss: 0.5134 - val_accuracy: 0.8600
# Epoch 216/1000
#  - 1s - loss: 1.6109e-04 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.8600
# Epoch 217/1000
#  - 1s - loss: 1.9508e-04 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.8600
# Epoch 218/1000
#  - 1s - loss: 2.0722e-04 - accuracy: 1.0000 - val_loss: 0.5176 - val_accuracy: 0.8600
# Epoch 219/1000
#  - 1s - loss: 1.6024e-04 - accuracy: 1.0000 - val_loss: 0.5191 - val_accuracy: 0.8600
# Epoch 220/1000
#  - 1s - loss: 2.0683e-04 - accuracy: 1.0000 - val_loss: 0.5205 - val_accuracy: 0.8600
# Epoch 221/1000
#  - 1s - loss: 1.6172e-04 - accuracy: 1.0000 - val_loss: 0.5221 - val_accuracy: 0.8600
# Epoch 222/1000
#  - 1s - loss: 2.6552e-04 - accuracy: 1.0000 - val_loss: 0.5245 - val_accuracy: 0.8600
# Epoch 223/1000
#  - 1s - loss: 1.5397e-04 - accuracy: 1.0000 - val_loss: 0.5269 - val_accuracy: 0.8600
# Epoch 224/1000
#  - 1s - loss: 1.6949e-04 - accuracy: 1.0000 - val_loss: 0.5291 - val_accuracy: 0.8600
# Epoch 225/1000
#  - 1s - loss: 1.6977e-04 - accuracy: 1.0000 - val_loss: 0.5305 - val_accuracy: 0.8600
# Epoch 226/1000
#  - 1s - loss: 1.7602e-04 - accuracy: 1.0000 - val_loss: 0.5319 - val_accuracy: 0.8600
# Epoch 227/1000
#  - 1s - loss: 1.9974e-04 - accuracy: 1.0000 - val_loss: 0.5333 - val_accuracy: 0.8600
# Epoch 228/1000
#  - 1s - loss: 2.4470e-04 - accuracy: 1.0000 - val_loss: 0.5352 - val_accuracy: 0.8600
# Epoch 229/1000
#  - 1s - loss: 3.3509e-04 - accuracy: 1.0000 - val_loss: 0.5367 - val_accuracy: 0.8600
# Epoch 230/1000
#  - 1s - loss: 1.7448e-04 - accuracy: 1.0000 - val_loss: 0.5385 - val_accuracy: 0.8600
# Epoch 231/1000
#  - 1s - loss: 2.1907e-04 - accuracy: 1.0000 - val_loss: 0.5404 - val_accuracy: 0.8600
# Epoch 232/1000
#  - 1s - loss: 2.4160e-04 - accuracy: 1.0000 - val_loss: 0.5421 - val_accuracy: 0.8600
# Epoch 233/1000
#  - 1s - loss: 2.0832e-04 - accuracy: 1.0000 - val_loss: 0.5439 - val_accuracy: 0.8600
# Epoch 234/1000
#  - 1s - loss: 1.6425e-04 - accuracy: 1.0000 - val_loss: 0.5448 - val_accuracy: 0.8600
# Epoch 235/1000
#  - 1s - loss: 1.8357e-04 - accuracy: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.8600
# Epoch 236/1000
#  - 1s - loss: 1.9728e-04 - accuracy: 1.0000 - val_loss: 0.5475 - val_accuracy: 0.8600
# Epoch 237/1000
#  - 1s - loss: 1.6377e-04 - accuracy: 1.0000 - val_loss: 0.5489 - val_accuracy: 0.8600
# Epoch 238/1000
#  - 1s - loss: 1.7792e-04 - accuracy: 1.0000 - val_loss: 0.5506 - val_accuracy: 0.8600
# Epoch 239/1000
#  - 1s - loss: 9.7274e-05 - accuracy: 1.0000 - val_loss: 0.5522 - val_accuracy: 0.8600
# Epoch 240/1000
#  - 1s - loss: 1.4810e-04 - accuracy: 1.0000 - val_loss: 0.5539 - val_accuracy: 0.8600
# Epoch 241/1000
#  - 1s - loss: 2.0790e-04 - accuracy: 1.0000 - val_loss: 0.5560 - val_accuracy: 0.8600
# Epoch 242/1000
#  - 1s - loss: 1.7349e-04 - accuracy: 1.0000 - val_loss: 0.5581 - val_accuracy: 0.8600
# Epoch 243/1000
#  - 1s - loss: 1.9410e-04 - accuracy: 1.0000 - val_loss: 0.5603 - val_accuracy: 0.8600
# Epoch 244/1000
#  - 1s - loss: 1.9010e-04 - accuracy: 1.0000 - val_loss: 0.5623 - val_accuracy: 0.8600
# Epoch 245/1000
#  - 1s - loss: 1.7989e-04 - accuracy: 1.0000 - val_loss: 0.5643 - val_accuracy: 0.8600
# Epoch 246/1000
#  - 1s - loss: 2.0473e-04 - accuracy: 1.0000 - val_loss: 0.5663 - val_accuracy: 0.8600
# Epoch 247/1000
#  - 1s - loss: 2.4408e-04 - accuracy: 1.0000 - val_loss: 0.5681 - val_accuracy: 0.8600
# Epoch 248/1000
#  - 1s - loss: 2.0039e-04 - accuracy: 1.0000 - val_loss: 0.5698 - val_accuracy: 0.8600
# Epoch 249/1000
#  - 1s - loss: 1.4674e-04 - accuracy: 1.0000 - val_loss: 0.5710 - val_accuracy: 0.8600
# Epoch 250/1000
#  - 1s - loss: 1.4910e-04 - accuracy: 1.0000 - val_loss: 0.5724 - val_accuracy: 0.8600
# Epoch 251/1000
#  - 1s - loss: 1.5280e-04 - accuracy: 1.0000 - val_loss: 0.5739 - val_accuracy: 0.8600
# Epoch 252/1000
#  - 1s - loss: 1.6029e-04 - accuracy: 1.0000 - val_loss: 0.5748 - val_accuracy: 0.8600
# Epoch 253/1000
#  - 1s - loss: 1.8644e-04 - accuracy: 1.0000 - val_loss: 0.5757 - val_accuracy: 0.8600
# Epoch 254/1000
#  - 1s - loss: 1.5541e-04 - accuracy: 1.0000 - val_loss: 0.5766 - val_accuracy: 0.8500
# Epoch 255/1000
#  - 1s - loss: 1.2091e-04 - accuracy: 1.0000 - val_loss: 0.5778 - val_accuracy: 0.8500
# Epoch 256/1000
#  - 1s - loss: 1.2716e-04 - accuracy: 1.0000 - val_loss: 0.5793 - val_accuracy: 0.8500
# Epoch 257/1000
#  - 1s - loss: 1.2177e-04 - accuracy: 1.0000 - val_loss: 0.5809 - val_accuracy: 0.8500
# Epoch 258/1000
#  - 1s - loss: 1.3535e-04 - accuracy: 1.0000 - val_loss: 0.5825 - val_accuracy: 0.8500
# Epoch 259/1000
#  - 1s - loss: 1.0944e-04 - accuracy: 1.0000 - val_loss: 0.5842 - val_accuracy: 0.8500
# Epoch 260/1000
#  - 1s - loss: 1.3506e-04 - accuracy: 1.0000 - val_loss: 0.5858 - val_accuracy: 0.8500
# Epoch 261/1000
#  - 1s - loss: 1.1477e-04 - accuracy: 1.0000 - val_loss: 0.5875 - val_accuracy: 0.8500
# Epoch 262/1000
#  - 1s - loss: 1.3698e-04 - accuracy: 1.0000 - val_loss: 0.5896 - val_accuracy: 0.8500
# Epoch 263/1000
#  - 1s - loss: 1.8155e-04 - accuracy: 1.0000 - val_loss: 0.5916 - val_accuracy: 0.8500
# Epoch 264/1000
#  - 1s - loss: 1.2979e-04 - accuracy: 1.0000 - val_loss: 0.5939 - val_accuracy: 0.8500
# Epoch 265/1000
#  - 1s - loss: 1.0252e-04 - accuracy: 1.0000 - val_loss: 0.5963 - val_accuracy: 0.8500
# Epoch 266/1000
#  - 1s - loss: 1.2004e-04 - accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.8500
# Epoch 267/1000
#  - 1s - loss: 1.9211e-04 - accuracy: 1.0000 - val_loss: 0.6009 - val_accuracy: 0.8500
# Epoch 268/1000
#  - 1s - loss: 1.1397e-04 - accuracy: 1.0000 - val_loss: 0.6032 - val_accuracy: 0.8500
# Epoch 269/1000
#  - 1s - loss: 1.7168e-04 - accuracy: 1.0000 - val_loss: 0.6056 - val_accuracy: 0.8500
# Epoch 270/1000
#  - 1s - loss: 1.4801e-04 - accuracy: 1.0000 - val_loss: 0.6081 - val_accuracy: 0.8500
# Epoch 271/1000
#  - 1s - loss: 1.2280e-04 - accuracy: 1.0000 - val_loss: 0.6107 - val_accuracy: 0.8500
# Epoch 272/1000
#  - 1s - loss: 1.0939e-04 - accuracy: 1.0000 - val_loss: 0.6130 - val_accuracy: 0.8500
# Epoch 273/1000
#  - 1s - loss: 1.7365e-04 - accuracy: 1.0000 - val_loss: 0.6154 - val_accuracy: 0.8500
# Epoch 274/1000
#  - 1s - loss: 1.7014e-04 - accuracy: 1.0000 - val_loss: 0.6179 - val_accuracy: 0.8500
# Epoch 275/1000
#  - 1s - loss: 1.1614e-04 - accuracy: 1.0000 - val_loss: 0.6209 - val_accuracy: 0.8500
# Epoch 276/1000
#  - 1s - loss: 1.0327e-04 - accuracy: 1.0000 - val_loss: 0.6240 - val_accuracy: 0.8500
# Epoch 277/1000
#  - 1s - loss: 1.2854e-04 - accuracy: 1.0000 - val_loss: 0.6271 - val_accuracy: 0.8500
# Epoch 278/1000
#  - 1s - loss: 1.9594e-04 - accuracy: 1.0000 - val_loss: 0.6299 - val_accuracy: 0.8500
# Epoch 279/1000
#  - 1s - loss: 2.2632e-04 - accuracy: 1.0000 - val_loss: 0.6329 - val_accuracy: 0.8500
# Epoch 280/1000
#  - 1s - loss: 7.9066e-05 - accuracy: 1.0000 - val_loss: 0.6357 - val_accuracy: 0.8600
# Epoch 281/1000
#  - 1s - loss: 1.3879e-04 - accuracy: 1.0000 - val_loss: 0.6377 - val_accuracy: 0.8600
# Epoch 282/1000
#  - 1s - loss: 1.3916e-04 - accuracy: 1.0000 - val_loss: 0.6398 - val_accuracy: 0.8600
# Epoch 283/1000
#  - 1s - loss: 1.1555e-04 - accuracy: 1.0000 - val_loss: 0.6416 - val_accuracy: 0.8600
# Epoch 284/1000
#  - 1s - loss: 1.3252e-04 - accuracy: 1.0000 - val_loss: 0.6436 - val_accuracy: 0.8600
# Epoch 285/1000
#  - 1s - loss: 1.0386e-04 - accuracy: 1.0000 - val_loss: 0.6452 - val_accuracy: 0.8600
# Epoch 286/1000
#  - 1s - loss: 1.3890e-04 - accuracy: 1.0000 - val_loss: 0.6470 - val_accuracy: 0.8600
# Epoch 287/1000
#  - 1s - loss: 1.7631e-04 - accuracy: 1.0000 - val_loss: 0.6490 - val_accuracy: 0.8600
# Epoch 288/1000
#  - 1s - loss: 1.8014e-04 - accuracy: 1.0000 - val_loss: 0.6505 - val_accuracy: 0.8600
# Epoch 289/1000
#  - 1s - loss: 9.1224e-05 - accuracy: 1.0000 - val_loss: 0.6519 - val_accuracy: 0.8600
# Epoch 290/1000
#  - 1s - loss: 1.6193e-04 - accuracy: 1.0000 - val_loss: 0.6533 - val_accuracy: 0.8600
# Epoch 291/1000
#  - 1s - loss: 1.0941e-04 - accuracy: 1.0000 - val_loss: 0.6547 - val_accuracy: 0.8600
# Epoch 292/1000
#  - 1s - loss: 1.6098e-04 - accuracy: 1.0000 - val_loss: 0.6561 - val_accuracy: 0.8600
# Epoch 293/1000
#  - 1s - loss: 1.2068e-04 - accuracy: 1.0000 - val_loss: 0.6579 - val_accuracy: 0.8600
# Epoch 294/1000
#  - 1s - loss: 1.1892e-04 - accuracy: 1.0000 - val_loss: 0.6601 - val_accuracy: 0.8600
# Epoch 295/1000
#  - 1s - loss: 9.9127e-05 - accuracy: 1.0000 - val_loss: 0.6618 - val_accuracy: 0.8600
# Epoch 296/1000
#  - 1s - loss: 1.3111e-04 - accuracy: 1.0000 - val_loss: 0.6630 - val_accuracy: 0.8600
# Epoch 297/1000
#  - 1s - loss: 1.2079e-04 - accuracy: 1.0000 - val_loss: 0.6646 - val_accuracy: 0.8600
# Epoch 298/1000
#  - 1s - loss: 9.9504e-05 - accuracy: 1.0000 - val_loss: 0.6661 - val_accuracy: 0.8600
# Epoch 299/1000
#  - 1s - loss: 1.0604e-04 - accuracy: 1.0000 - val_loss: 0.6674 - val_accuracy: 0.8600
# Epoch 300/1000
#  - 1s - loss: 9.5254e-05 - accuracy: 1.0000 - val_loss: 0.6688 - val_accuracy: 0.8600
# Epoch 301/1000
#  - 1s - loss: 8.7443e-05 - accuracy: 1.0000 - val_loss: 0.6700 - val_accuracy: 0.8600
# Epoch 302/1000
#  - 1s - loss: 9.8928e-05 - accuracy: 1.0000 - val_loss: 0.6711 - val_accuracy: 0.8500
# Epoch 303/1000
#  - 1s - loss: 8.9114e-05 - accuracy: 1.0000 - val_loss: 0.6720 - val_accuracy: 0.8500
# Epoch 304/1000
#  - 1s - loss: 1.4002e-04 - accuracy: 1.0000 - val_loss: 0.6729 - val_accuracy: 0.8500
# Epoch 305/1000
#  - 1s - loss: 9.4613e-05 - accuracy: 1.0000 - val_loss: 0.6744 - val_accuracy: 0.8600
# Epoch 306/1000
#  - 1s - loss: 1.0813e-04 - accuracy: 1.0000 - val_loss: 0.6762 - val_accuracy: 0.8600
# Epoch 307/1000
#  - 1s - loss: 9.4023e-05 - accuracy: 1.0000 - val_loss: 0.6780 - val_accuracy: 0.8600
# Epoch 308/1000
#  - 1s - loss: 8.6019e-05 - accuracy: 1.0000 - val_loss: 0.6800 - val_accuracy: 0.8600
# Epoch 309/1000
#  - 1s - loss: 1.2256e-04 - accuracy: 1.0000 - val_loss: 0.6821 - val_accuracy: 0.8600
# Epoch 310/1000
#  - 1s - loss: 1.2640e-04 - accuracy: 1.0000 - val_loss: 0.6847 - val_accuracy: 0.8600
# Epoch 311/1000
#  - 1s - loss: 6.8598e-05 - accuracy: 1.0000 - val_loss: 0.6877 - val_accuracy: 0.8500
# Epoch 312/1000
#  - 1s - loss: 1.0415e-04 - accuracy: 1.0000 - val_loss: 0.6903 - val_accuracy: 0.8500
# Epoch 313/1000
#  - 1s - loss: 1.2791e-04 - accuracy: 1.0000 - val_loss: 0.6926 - val_accuracy: 0.8600
# Epoch 314/1000
#  - 1s - loss: 9.5569e-05 - accuracy: 1.0000 - val_loss: 0.6948 - val_accuracy: 0.8600
# Epoch 315/1000
#  - 1s - loss: 8.4511e-05 - accuracy: 1.0000 - val_loss: 0.6970 - val_accuracy: 0.8600
# Epoch 316/1000
#  - 1s - loss: 1.0817e-04 - accuracy: 1.0000 - val_loss: 0.6991 - val_accuracy: 0.8600
# Epoch 317/1000
#  - 1s - loss: 8.8958e-05 - accuracy: 1.0000 - val_loss: 0.7009 - val_accuracy: 0.8600
# Epoch 318/1000
#  - 1s - loss: 6.5365e-05 - accuracy: 1.0000 - val_loss: 0.7027 - val_accuracy: 0.8600
# Epoch 319/1000
#  - 1s - loss: 1.1247e-04 - accuracy: 1.0000 - val_loss: 0.7045 - val_accuracy: 0.8600
# Epoch 320/1000
#  - 1s - loss: 1.0171e-04 - accuracy: 1.0000 - val_loss: 0.7062 - val_accuracy: 0.8700
# Epoch 321/1000
#  - 1s - loss: 1.4483e-04 - accuracy: 1.0000 - val_loss: 0.7079 - val_accuracy: 0.8700
# Epoch 322/1000
#  - 1s - loss: 1.2482e-04 - accuracy: 1.0000 - val_loss: 0.7089 - val_accuracy: 0.8700
# Epoch 323/1000
#  - 1s - loss: 1.0853e-04 - accuracy: 1.0000 - val_loss: 0.7101 - val_accuracy: 0.8700
# Epoch 324/1000
#  - 1s - loss: 9.9962e-05 - accuracy: 1.0000 - val_loss: 0.7117 - val_accuracy: 0.8700
# Epoch 325/1000
#  - 1s - loss: 1.1738e-04 - accuracy: 1.0000 - val_loss: 0.7130 - val_accuracy: 0.8700
# Epoch 326/1000
#  - 1s - loss: 1.0308e-04 - accuracy: 1.0000 - val_loss: 0.7145 - val_accuracy: 0.8700
# Epoch 327/1000
#  - 1s - loss: 1.5644e-04 - accuracy: 1.0000 - val_loss: 0.7164 - val_accuracy: 0.8600
# Epoch 328/1000
#  - 1s - loss: 1.1388e-04 - accuracy: 1.0000 - val_loss: 0.7180 - val_accuracy: 0.8600
# Epoch 329/1000
#  - 1s - loss: 8.1911e-05 - accuracy: 1.0000 - val_loss: 0.7193 - val_accuracy: 0.8600
# Epoch 330/1000
#  - 1s - loss: 1.0863e-04 - accuracy: 1.0000 - val_loss: 0.7212 - val_accuracy: 0.8600
# Epoch 331/1000
#  - 1s - loss: 8.8120e-05 - accuracy: 1.0000 - val_loss: 0.7228 - val_accuracy: 0.8600
# Epoch 332/1000
#  - 1s - loss: 1.3466e-04 - accuracy: 1.0000 - val_loss: 0.7247 - val_accuracy: 0.8600
# Epoch 333/1000
#  - 1s - loss: 8.3912e-05 - accuracy: 1.0000 - val_loss: 0.7263 - val_accuracy: 0.8700
# Epoch 334/1000
#  - 1s - loss: 1.0039e-04 - accuracy: 1.0000 - val_loss: 0.7274 - val_accuracy: 0.8600
# Epoch 335/1000
#  - 1s - loss: 7.7877e-05 - accuracy: 1.0000 - val_loss: 0.7287 - val_accuracy: 0.8600
# Epoch 336/1000
#  - 1s - loss: 1.5654e-04 - accuracy: 1.0000 - val_loss: 0.7297 - val_accuracy: 0.8600
# Epoch 337/1000
#  - 1s - loss: 9.9011e-05 - accuracy: 1.0000 - val_loss: 0.7310 - val_accuracy: 0.8700
# Epoch 338/1000
#  - 1s - loss: 8.9484e-05 - accuracy: 1.0000 - val_loss: 0.7322 - val_accuracy: 0.8700
# Epoch 339/1000
#  - 1s - loss: 9.6571e-05 - accuracy: 1.0000 - val_loss: 0.7334 - val_accuracy: 0.8600
# Epoch 340/1000
#  - 1s - loss: 5.4487e-05 - accuracy: 1.0000 - val_loss: 0.7346 - val_accuracy: 0.8600
# Epoch 341/1000
#  - 1s - loss: 6.4417e-05 - accuracy: 1.0000 - val_loss: 0.7360 - val_accuracy: 0.8600
# Epoch 342/1000
#  - 1s - loss: 6.5745e-05 - accuracy: 1.0000 - val_loss: 0.7375 - val_accuracy: 0.8600
# Epoch 343/1000
#  - 1s - loss: 1.0160e-04 - accuracy: 1.0000 - val_loss: 0.7389 - val_accuracy: 0.8600
# Epoch 344/1000
#  - 1s - loss: 7.8547e-05 - accuracy: 1.0000 - val_loss: 0.7404 - val_accuracy: 0.8600
# Epoch 345/1000
#  - 1s - loss: 7.0487e-05 - accuracy: 1.0000 - val_loss: 0.7418 - val_accuracy: 0.8600
# Epoch 346/1000
#  - 1s - loss: 1.1365e-04 - accuracy: 1.0000 - val_loss: 0.7433 - val_accuracy: 0.8600
# Epoch 347/1000
#  - 1s - loss: 1.3134e-04 - accuracy: 1.0000 - val_loss: 0.7447 - val_accuracy: 0.8600
# Epoch 348/1000
#  - 1s - loss: 9.7838e-05 - accuracy: 1.0000 - val_loss: 0.7456 - val_accuracy: 0.8600
# Epoch 349/1000
#  - 1s - loss: 8.3968e-05 - accuracy: 1.0000 - val_loss: 0.7463 - val_accuracy: 0.8600
# Epoch 350/1000
#  - 1s - loss: 8.5159e-05 - accuracy: 1.0000 - val_loss: 0.7470 - val_accuracy: 0.8600
# Epoch 351/1000
#  - 1s - loss: 8.4580e-05 - accuracy: 1.0000 - val_loss: 0.7479 - val_accuracy: 0.8600
# Epoch 352/1000
#  - 1s - loss: 8.9534e-05 - accuracy: 1.0000 - val_loss: 0.7492 - val_accuracy: 0.8600
# Epoch 353/1000
#  - 1s - loss: 7.2921e-05 - accuracy: 1.0000 - val_loss: 0.7508 - val_accuracy: 0.8600
# Epoch 354/1000
#  - 1s - loss: 6.0587e-05 - accuracy: 1.0000 - val_loss: 0.7523 - val_accuracy: 0.8600
# Epoch 355/1000
#  - 1s - loss: 8.3827e-05 - accuracy: 1.0000 - val_loss: 0.7538 - val_accuracy: 0.8600
# Epoch 356/1000
#  - 1s - loss: 1.4873e-04 - accuracy: 1.0000 - val_loss: 0.7546 - val_accuracy: 0.8600
# Epoch 357/1000
#  - 1s - loss: 6.7564e-05 - accuracy: 1.0000 - val_loss: 0.7556 - val_accuracy: 0.8600
# Epoch 358/1000
#  - 1s - loss: 5.1997e-05 - accuracy: 1.0000 - val_loss: 0.7569 - val_accuracy: 0.8600
# Epoch 359/1000
#  - 1s - loss: 7.8332e-05 - accuracy: 1.0000 - val_loss: 0.7584 - val_accuracy: 0.8600
# Epoch 360/1000
#  - 1s - loss: 6.5318e-05 - accuracy: 1.0000 - val_loss: 0.7598 - val_accuracy: 0.8600
# Epoch 361/1000
#  - 1s - loss: 6.0095e-05 - accuracy: 1.0000 - val_loss: 0.7613 - val_accuracy: 0.8600
# Epoch 362/1000
#  - 1s - loss: 8.7870e-05 - accuracy: 1.0000 - val_loss: 0.7628 - val_accuracy: 0.8600
# Epoch 363/1000
#  - 1s - loss: 7.6895e-05 - accuracy: 1.0000 - val_loss: 0.7642 - val_accuracy: 0.8600
# Epoch 364/1000
#  - 1s - loss: 9.0538e-05 - accuracy: 1.0000 - val_loss: 0.7655 - val_accuracy: 0.8600
# Epoch 365/1000
#  - 1s - loss: 9.3640e-05 - accuracy: 1.0000 - val_loss: 0.7665 - val_accuracy: 0.8600
# Epoch 366/1000
#  - 1s - loss: 1.5785e-04 - accuracy: 1.0000 - val_loss: 0.7676 - val_accuracy: 0.8600
# Epoch 367/1000
#  - 1s - loss: 9.0418e-05 - accuracy: 1.0000 - val_loss: 0.7688 - val_accuracy: 0.8600
# Epoch 368/1000
#  - 1s - loss: 6.8971e-05 - accuracy: 1.0000 - val_loss: 0.7702 - val_accuracy: 0.8600
# Epoch 369/1000
#  - 1s - loss: 1.0371e-04 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.8600
# Epoch 370/1000
#  - 1s - loss: 7.0907e-05 - accuracy: 1.0000 - val_loss: 0.7726 - val_accuracy: 0.8600
# Epoch 371/1000
#  - 1s - loss: 7.1778e-05 - accuracy: 1.0000 - val_loss: 0.7732 - val_accuracy: 0.8600
# Epoch 372/1000
#  - 1s - loss: 7.2188e-05 - accuracy: 1.0000 - val_loss: 0.7740 - val_accuracy: 0.8600
# Epoch 373/1000
#  - 1s - loss: 9.7815e-05 - accuracy: 1.0000 - val_loss: 0.7753 - val_accuracy: 0.8600
# Epoch 374/1000
#  - 1s - loss: 9.8621e-05 - accuracy: 1.0000 - val_loss: 0.7765 - val_accuracy: 0.8600
# Epoch 375/1000
#  - 1s - loss: 9.2067e-05 - accuracy: 1.0000 - val_loss: 0.7774 - val_accuracy: 0.8600
# Epoch 376/1000
#  - 1s - loss: 1.0791e-04 - accuracy: 1.0000 - val_loss: 0.7789 - val_accuracy: 0.8600
# Epoch 377/1000
#  - 1s - loss: 6.8434e-05 - accuracy: 1.0000 - val_loss: 0.7804 - val_accuracy: 0.8600
# Epoch 378/1000
#  - 1s - loss: 8.0563e-05 - accuracy: 1.0000 - val_loss: 0.7817 - val_accuracy: 0.8600
# Epoch 379/1000
#  - 1s - loss: 5.7899e-05 - accuracy: 1.0000 - val_loss: 0.7830 - val_accuracy: 0.8600
# Epoch 380/1000
#  - 1s - loss: 5.7862e-05 - accuracy: 1.0000 - val_loss: 0.7843 - val_accuracy: 0.8600
# Epoch 381/1000
#  - 1s - loss: 7.6567e-05 - accuracy: 1.0000 - val_loss: 0.7856 - val_accuracy: 0.8600
# Epoch 382/1000
#  - 1s - loss: 1.0161e-04 - accuracy: 1.0000 - val_loss: 0.7873 - val_accuracy: 0.8600
# Epoch 383/1000
#  - 1s - loss: 7.3350e-05 - accuracy: 1.0000 - val_loss: 0.7887 - val_accuracy: 0.8600
# Epoch 384/1000
#  - 1s - loss: 7.8243e-05 - accuracy: 1.0000 - val_loss: 0.7901 - val_accuracy: 0.8600
# Epoch 385/1000
#  - 1s - loss: 9.9733e-05 - accuracy: 1.0000 - val_loss: 0.7918 - val_accuracy: 0.8600
# Epoch 386/1000
#  - 1s - loss: 2.0880e-04 - accuracy: 1.0000 - val_loss: 0.7925 - val_accuracy: 0.8600
# Epoch 387/1000
#  - 1s - loss: 7.0543e-05 - accuracy: 1.0000 - val_loss: 0.7933 - val_accuracy: 0.8600
# Epoch 388/1000
#  - 1s - loss: 6.9333e-05 - accuracy: 1.0000 - val_loss: 0.7942 - val_accuracy: 0.8600
# Epoch 389/1000
#  - 1s - loss: 6.1320e-05 - accuracy: 1.0000 - val_loss: 0.7953 - val_accuracy: 0.8600
# Epoch 390/1000
#  - 1s - loss: 7.4865e-05 - accuracy: 1.0000 - val_loss: 0.7962 - val_accuracy: 0.8600
# Epoch 391/1000
#  - 1s - loss: 7.0809e-05 - accuracy: 1.0000 - val_loss: 0.7970 - val_accuracy: 0.8600
# Epoch 392/1000
#  - 1s - loss: 7.0176e-05 - accuracy: 1.0000 - val_loss: 0.7978 - val_accuracy: 0.8600
# Epoch 393/1000
#  - 1s - loss: 9.0487e-05 - accuracy: 1.0000 - val_loss: 0.7987 - val_accuracy: 0.8600
# Epoch 394/1000
#  - 1s - loss: 1.0157e-04 - accuracy: 1.0000 - val_loss: 0.7999 - val_accuracy: 0.8600
# Epoch 395/1000
#  - 1s - loss: 1.1008e-04 - accuracy: 1.0000 - val_loss: 0.8010 - val_accuracy: 0.8600
# Epoch 396/1000
#  - 1s - loss: 8.1987e-05 - accuracy: 1.0000 - val_loss: 0.8023 - val_accuracy: 0.8600
# Epoch 397/1000
#  - 1s - loss: 1.0880e-04 - accuracy: 1.0000 - val_loss: 0.8033 - val_accuracy: 0.8600
# Epoch 398/1000
#  - 1s - loss: 6.7293e-05 - accuracy: 1.0000 - val_loss: 0.8045 - val_accuracy: 0.8600
# Epoch 399/1000
#  - 1s - loss: 5.2132e-05 - accuracy: 1.0000 - val_loss: 0.8055 - val_accuracy: 0.8600
# Epoch 400/1000
#  - 1s - loss: 7.8394e-05 - accuracy: 1.0000 - val_loss: 0.8068 - val_accuracy: 0.8600
# Epoch 401/1000
#  - 1s - loss: 8.2043e-05 - accuracy: 1.0000 - val_loss: 0.8082 - val_accuracy: 0.8600
# Epoch 402/1000
#  - 1s - loss: 5.3811e-05 - accuracy: 1.0000 - val_loss: 0.8096 - val_accuracy: 0.8600
# Epoch 403/1000
#  - 1s - loss: 9.3103e-05 - accuracy: 1.0000 - val_loss: 0.8114 - val_accuracy: 0.8600
# Epoch 404/1000
# ...
# Epoch 872/1000
#  - 1s - loss: 1.8014e-05 - accuracy: 1.0000 - val_loss: 1.0160 - val_accuracy: 0.8800
# Epoch 873/1000
#  - 1s - loss: 1.5817e-05 - accuracy: 1.0000 - val_loss: 1.0161 - val_accuracy: 0.8800
# Epoch 874/1000
#  - 1s - loss: 1.8559e-05 - accuracy: 1.0000 - val_loss: 1.0162 - val_accuracy: 0.8800
# Epoch 875/1000
#  - 1s - loss: 1.4908e-05 - accuracy: 1.0000 - val_loss: 1.0164 - val_accuracy: 0.8800
# Epoch 876/1000
#  - 1s - loss: 2.2471e-05 - accuracy: 1.0000 - val_loss: 1.0166 - val_accuracy: 0.8800
# Epoch 877/1000
#  - 1s - loss: 2.1155e-05 - accuracy: 1.0000 - val_loss: 1.0168 - val_accuracy: 0.8800
# Epoch 878/1000
#  - 1s - loss: 1.9229e-05 - accuracy: 1.0000 - val_loss: 1.0169 - val_accuracy: 0.8800
# Epoch 879/1000
#  - 1s - loss: 2.8151e-05 - accuracy: 1.0000 - val_loss: 1.0174 - val_accuracy: 0.8800
# Epoch 880/1000
#  - 1s - loss: 2.2042e-05 - accuracy: 1.0000 - val_loss: 1.0175 - val_accuracy: 0.8800
# Epoch 881/1000
#  - 1s - loss: 3.2458e-05 - accuracy: 1.0000 - val_loss: 1.0174 - val_accuracy: 0.8800
# Epoch 882/1000
#  - 1s - loss: 1.7854e-05 - accuracy: 1.0000 - val_loss: 1.0172 - val_accuracy: 0.8800
# Epoch 883/1000
#  - 1s - loss: 2.2049e-05 - accuracy: 1.0000 - val_loss: 1.0171 - val_accuracy: 0.8800
# Epoch 884/1000
#  - 1s - loss: 1.7959e-05 - accuracy: 1.0000 - val_loss: 1.0170 - val_accuracy: 0.8800
# Epoch 885/1000
#  - 1s - loss: 2.4286e-05 - accuracy: 1.0000 - val_loss: 1.0173 - val_accuracy: 0.8800
# Epoch 886/1000
#  - 1s - loss: 1.6681e-05 - accuracy: 1.0000 - val_loss: 1.0175 - val_accuracy: 0.8800
# Epoch 887/1000
#  - 1s - loss: 1.5185e-05 - accuracy: 1.0000 - val_loss: 1.0175 - val_accuracy: 0.8800
# Epoch 888/1000
#  - 1s - loss: 2.7763e-05 - accuracy: 1.0000 - val_loss: 1.0178 - val_accuracy: 0.8800
# Epoch 889/1000
#  - 1s - loss: 2.1001e-05 - accuracy: 1.0000 - val_loss: 1.0180 - val_accuracy: 0.8800
# Epoch 890/1000
#  - 1s - loss: 2.5376e-05 - accuracy: 1.0000 - val_loss: 1.0183 - val_accuracy: 0.8800
# Epoch 891/1000
#  - 1s - loss: 1.7086e-05 - accuracy: 1.0000 - val_loss: 1.0184 - val_accuracy: 0.8800
# Epoch 892/1000
#  - 1s - loss: 2.0600e-05 - accuracy: 1.0000 - val_loss: 1.0183 - val_accuracy: 0.8800
# Epoch 893/1000
#  - 1s - loss: 1.9604e-05 - accuracy: 1.0000 - val_loss: 1.0186 - val_accuracy: 0.8800
# Epoch 894/1000
#  - 1s - loss: 3.2811e-05 - accuracy: 1.0000 - val_loss: 1.0194 - val_accuracy: 0.8800
# Epoch 895/1000
#  - 1s - loss: 1.7925e-05 - accuracy: 1.0000 - val_loss: 1.0201 - val_accuracy: 0.8800
# Epoch 896/1000
#  - 1s - loss: 1.9551e-05 - accuracy: 1.0000 - val_loss: 1.0207 - val_accuracy: 0.8800
# Epoch 897/1000
#  - 1s - loss: 2.4975e-05 - accuracy: 1.0000 - val_loss: 1.0211 - val_accuracy: 0.8800
# Epoch 898/1000
#  - 1s - loss: 4.0296e-05 - accuracy: 1.0000 - val_loss: 1.0219 - val_accuracy: 0.8800
# Epoch 899/1000
#  - 1s - loss: 1.8064e-05 - accuracy: 1.0000 - val_loss: 1.0226 - val_accuracy: 0.8800
# Epoch 900/1000
#  - 1s - loss: 2.5800e-05 - accuracy: 1.0000 - val_loss: 1.0228 - val_accuracy: 0.8800
# Epoch 901/1000
#  - 1s - loss: 1.7357e-05 - accuracy: 1.0000 - val_loss: 1.0228 - val_accuracy: 0.8800
# Epoch 902/1000
#  - 1s - loss: 1.7834e-05 - accuracy: 1.0000 - val_loss: 1.0227 - val_accuracy: 0.8800
# Epoch 903/1000
#  - 1s - loss: 1.1843e-05 - accuracy: 1.0000 - val_loss: 1.0227 - val_accuracy: 0.8800
# Epoch 904/1000
#  - 1s - loss: 1.3064e-05 - accuracy: 1.0000 - val_loss: 1.0225 - val_accuracy: 0.8800
# Epoch 905/1000
#  - 1s - loss: 1.3931e-05 - accuracy: 1.0000 - val_loss: 1.0221 - val_accuracy: 0.8800
# Epoch 906/1000
#  - 1s - loss: 2.0120e-05 - accuracy: 1.0000 - val_loss: 1.0217 - val_accuracy: 0.8800
# Epoch 907/1000
#  - 1s - loss: 2.3247e-05 - accuracy: 1.0000 - val_loss: 1.0216 - val_accuracy: 0.8800
# Epoch 908/1000
#  - 1s - loss: 1.3324e-05 - accuracy: 1.0000 - val_loss: 1.0213 - val_accuracy: 0.8800
# Epoch 909/1000
#  - 1s - loss: 2.3458e-05 - accuracy: 1.0000 - val_loss: 1.0214 - val_accuracy: 0.8800
# Epoch 910/1000
#  - 1s - loss: 2.6077e-05 - accuracy: 1.0000 - val_loss: 1.0215 - val_accuracy: 0.8800
# Epoch 911/1000
#  - 1s - loss: 1.7377e-05 - accuracy: 1.0000 - val_loss: 1.0216 - val_accuracy: 0.8800
# Epoch 912/1000
#  - 1s - loss: 2.4130e-05 - accuracy: 1.0000 - val_loss: 1.0217 - val_accuracy: 0.8800
# Epoch 913/1000
#  - 1s - loss: 1.4739e-05 - accuracy: 1.0000 - val_loss: 1.0216 - val_accuracy: 0.8800
# Epoch 914/1000
#  - 1s - loss: 1.9519e-05 - accuracy: 1.0000 - val_loss: 1.0215 - val_accuracy: 0.8800
# Epoch 915/1000
#  - 1s - loss: 1.3642e-05 - accuracy: 1.0000 - val_loss: 1.0214 - val_accuracy: 0.8800
# Epoch 916/1000
#  - 1s - loss: 1.8855e-05 - accuracy: 1.0000 - val_loss: 1.0215 - val_accuracy: 0.8800
# Epoch 917/1000
#  - 1s - loss: 1.7295e-05 - accuracy: 1.0000 - val_loss: 1.0211 - val_accuracy: 0.8800
# Epoch 918/1000
#  - 1s - loss: 1.8187e-05 - accuracy: 1.0000 - val_loss: 1.0209 - val_accuracy: 0.8800
# Epoch 919/1000
#  - 1s - loss: 2.8949e-05 - accuracy: 1.0000 - val_loss: 1.0206 - val_accuracy: 0.8800
# Epoch 920/1000
#  - 1s - loss: 2.4002e-05 - accuracy: 1.0000 - val_loss: 1.0200 - val_accuracy: 0.8800
# Epoch 921/1000
#  - 1s - loss: 1.7252e-05 - accuracy: 1.0000 - val_loss: 1.0193 - val_accuracy: 0.8800
# Epoch 922/1000
#  - 1s - loss: 2.7398e-05 - accuracy: 1.0000 - val_loss: 1.0184 - val_accuracy: 0.8800
# Epoch 923/1000
#  - 1s - loss: 1.5080e-05 - accuracy: 1.0000 - val_loss: 1.0175 - val_accuracy: 0.8800
# Epoch 924/1000
#  - 1s - loss: 1.1362e-05 - accuracy: 1.0000 - val_loss: 1.0167 - val_accuracy: 0.8800
# Epoch 925/1000
#  - 1s - loss: 1.7466e-05 - accuracy: 1.0000 - val_loss: 1.0162 - val_accuracy: 0.8800
# Epoch 926/1000
#  - 1s - loss: 1.8595e-05 - accuracy: 1.0000 - val_loss: 1.0159 - val_accuracy: 0.8800
# Epoch 927/1000
#  - 1s - loss: 2.5461e-05 - accuracy: 1.0000 - val_loss: 1.0157 - val_accuracy: 0.8800
# Epoch 928/1000
#  - 1s - loss: 1.8331e-05 - accuracy: 1.0000 - val_loss: 1.0157 - val_accuracy: 0.8800
# Epoch 929/1000
#  - 1s - loss: 1.1688e-05 - accuracy: 1.0000 - val_loss: 1.0157 - val_accuracy: 0.8800
# Epoch 930/1000
#  - 1s - loss: 1.7009e-05 - accuracy: 1.0000 - val_loss: 1.0156 - val_accuracy: 0.8800
# Epoch 931/1000
#  - 1s - loss: 1.3835e-05 - accuracy: 1.0000 - val_loss: 1.0156 - val_accuracy: 0.8700
# Epoch 932/1000
#  - 1s - loss: 2.2539e-05 - accuracy: 1.0000 - val_loss: 1.0158 - val_accuracy: 0.8700
# Epoch 933/1000
#  - 1s - loss: 1.8471e-05 - accuracy: 1.0000 - val_loss: 1.0160 - val_accuracy: 0.8600
# Epoch 934/1000
#  - 1s - loss: 1.4424e-05 - accuracy: 1.0000 - val_loss: 1.0163 - val_accuracy: 0.8600
# Epoch 935/1000
#  - 1s - loss: 2.6941e-05 - accuracy: 1.0000 - val_loss: 1.0164 - val_accuracy: 0.8700
# Epoch 936/1000
#  - 1s - loss: 1.9389e-05 - accuracy: 1.0000 - val_loss: 1.0167 - val_accuracy: 0.8800
# Epoch 937/1000
#  - 1s - loss: 1.7363e-05 - accuracy: 1.0000 - val_loss: 1.0171 - val_accuracy: 0.8800
# Epoch 938/1000
#  - 1s - loss: 1.2811e-05 - accuracy: 1.0000 - val_loss: 1.0174 - val_accuracy: 0.8800
# Epoch 939/1000
#  - 1s - loss: 1.3610e-05 - accuracy: 1.0000 - val_loss: 1.0179 - val_accuracy: 0.8800
# Epoch 940/1000
#  - 1s - loss: 1.2661e-05 - accuracy: 1.0000 - val_loss: 1.0183 - val_accuracy: 0.8800
# Epoch 941/1000
#  - 1s - loss: 1.7322e-05 - accuracy: 1.0000 - val_loss: 1.0186 - val_accuracy: 0.8800
# Epoch 942/1000
#  - 1s - loss: 1.3013e-05 - accuracy: 1.0000 - val_loss: 1.0189 - val_accuracy: 0.8800
# Epoch 943/1000
#  - 1s - loss: 4.0145e-05 - accuracy: 1.0000 - val_loss: 1.0193 - val_accuracy: 0.8800
# Epoch 944/1000
#  - 1s - loss: 1.4787e-05 - accuracy: 1.0000 - val_loss: 1.0197 - val_accuracy: 0.8800
# Epoch 945/1000
#  - 1s - loss: 1.2203e-05 - accuracy: 1.0000 - val_loss: 1.0201 - val_accuracy: 0.8800
# Epoch 946/1000
#  - 1s - loss: 1.9296e-05 - accuracy: 1.0000 - val_loss: 1.0205 - val_accuracy: 0.8800
# Epoch 947/1000
#  - 1s - loss: 1.4331e-05 - accuracy: 1.0000 - val_loss: 1.0208 - val_accuracy: 0.8800
# Epoch 948/1000
#  - 1s - loss: 3.0292e-05 - accuracy: 1.0000 - val_loss: 1.0205 - val_accuracy: 0.8800
# Epoch 949/1000
#  - 1s - loss: 2.3107e-05 - accuracy: 1.0000 - val_loss: 1.0201 - val_accuracy: 0.8800
# Epoch 950/1000
#  - 1s - loss: 1.6282e-05 - accuracy: 1.0000 - val_loss: 1.0196 - val_accuracy: 0.8800
# Epoch 951/1000
#  - 1s - loss: 2.7515e-05 - accuracy: 1.0000 - val_loss: 1.0198 - val_accuracy: 0.8800
# Epoch 952/1000
#  - 1s - loss: 1.3289e-05 - accuracy: 1.0000 - val_loss: 1.0197 - val_accuracy: 0.8800
# Epoch 953/1000
#  - 1s - loss: 1.3552e-05 - accuracy: 1.0000 - val_loss: 1.0195 - val_accuracy: 0.8800
# Epoch 954/1000
#  - 1s - loss: 1.1123e-05 - accuracy: 1.0000 - val_loss: 1.0193 - val_accuracy: 0.8800
# Epoch 955/1000
#  - 1s - loss: 1.8817e-05 - accuracy: 1.0000 - val_loss: 1.0194 - val_accuracy: 0.8800
# Epoch 956/1000
#  - 1s - loss: 1.8819e-05 - accuracy: 1.0000 - val_loss: 1.0197 - val_accuracy: 0.8800
# Epoch 957/1000
#  - 1s - loss: 1.3199e-05 - accuracy: 1.0000 - val_loss: 1.0196 - val_accuracy: 0.8800
# Epoch 958/1000
#  - 1s - loss: 3.0892e-05 - accuracy: 1.0000 - val_loss: 1.0199 - val_accuracy: 0.8800
# Epoch 959/1000
#  - 1s - loss: 1.5684e-05 - accuracy: 1.0000 - val_loss: 1.0200 - val_accuracy: 0.8800
# Epoch 960/1000
#  - 1s - loss: 1.2525e-05 - accuracy: 1.0000 - val_loss: 1.0202 - val_accuracy: 0.8800
# Epoch 961/1000
#  - 1s - loss: 1.6864e-05 - accuracy: 1.0000 - val_loss: 1.0195 - val_accuracy: 0.8800
# Epoch 962/1000
#  - 1s - loss: 1.6614e-05 - accuracy: 1.0000 - val_loss: 1.0189 - val_accuracy: 0.8800
# Epoch 963/1000
#  - 1s - loss: 1.4689e-05 - accuracy: 1.0000 - val_loss: 1.0181 - val_accuracy: 0.8800
# Epoch 964/1000
#  - 1s - loss: 1.2494e-05 - accuracy: 1.0000 - val_loss: 1.0176 - val_accuracy: 0.8700
# Epoch 965/1000
#  - 1s - loss: 3.0257e-05 - accuracy: 1.0000 - val_loss: 1.0173 - val_accuracy: 0.8700
# Epoch 966/1000
#  - 1s - loss: 2.1816e-05 - accuracy: 1.0000 - val_loss: 1.0175 - val_accuracy: 0.8700
# Epoch 967/1000
#  - 1s - loss: 2.3039e-05 - accuracy: 1.0000 - val_loss: 1.0178 - val_accuracy: 0.8600
# Epoch 968/1000
#  - 1s - loss: 1.4556e-05 - accuracy: 1.0000 - val_loss: 1.0182 - val_accuracy: 0.8600
# Epoch 969/1000
#  - 1s - loss: 2.0146e-05 - accuracy: 1.0000 - val_loss: 1.0188 - val_accuracy: 0.8600
# Epoch 970/1000
#  - 1s - loss: 1.7215e-05 - accuracy: 1.0000 - val_loss: 1.0192 - val_accuracy: 0.8600
# Epoch 971/1000
#  - 1s - loss: 1.6933e-05 - accuracy: 1.0000 - val_loss: 1.0196 - val_accuracy: 0.8600
# Epoch 972/1000
#  - 1s - loss: 1.7439e-05 - accuracy: 1.0000 - val_loss: 1.0202 - val_accuracy: 0.8600
# Epoch 973/1000
#  - 1s - loss: 1.4830e-05 - accuracy: 1.0000 - val_loss: 1.0208 - val_accuracy: 0.8600
# Epoch 974/1000
#  - 1s - loss: 1.4623e-05 - accuracy: 1.0000 - val_loss: 1.0216 - val_accuracy: 0.8700
# Epoch 975/1000
#  - 1s - loss: 1.1745e-05 - accuracy: 1.0000 - val_loss: 1.0224 - val_accuracy: 0.8700
# Epoch 976/1000
#  - 1s - loss: 1.6786e-05 - accuracy: 1.0000 - val_loss: 1.0232 - val_accuracy: 0.8700
# Epoch 977/1000
#  - 1s - loss: 1.2070e-05 - accuracy: 1.0000 - val_loss: 1.0239 - val_accuracy: 0.8800
# Epoch 978/1000
#  - 1s - loss: 1.2632e-05 - accuracy: 1.0000 - val_loss: 1.0246 - val_accuracy: 0.8800
# Epoch 979/1000
#  - 1s - loss: 1.9694e-05 - accuracy: 1.0000 - val_loss: 1.0251 - val_accuracy: 0.8800
# Epoch 980/1000
#  - 1s - loss: 1.9275e-05 - accuracy: 1.0000 - val_loss: 1.0257 - val_accuracy: 0.8800
# Epoch 981/1000
#  - 1s - loss: 1.7521e-05 - accuracy: 1.0000 - val_loss: 1.0262 - val_accuracy: 0.8800
# Epoch 982/1000
#  - 1s - loss: 1.2805e-05 - accuracy: 1.0000 - val_loss: 1.0267 - val_accuracy: 0.8800
# Epoch 983/1000
#  - 1s - loss: 1.7159e-05 - accuracy: 1.0000 - val_loss: 1.0269 - val_accuracy: 0.8800
# Epoch 984/1000
#  - 1s - loss: 1.1470e-05 - accuracy: 1.0000 - val_loss: 1.0272 - val_accuracy: 0.8800
# Epoch 985/1000
#  - 1s - loss: 1.4566e-05 - accuracy: 1.0000 - val_loss: 1.0273 - val_accuracy: 0.8800
# Epoch 986/1000
#  - 1s - loss: 1.3167e-05 - accuracy: 1.0000 - val_loss: 1.0275 - val_accuracy: 0.8800
# Epoch 987/1000
#  - 1s - loss: 1.6308e-05 - accuracy: 1.0000 - val_loss: 1.0277 - val_accuracy: 0.8800
# Epoch 988/1000
#  - 1s - loss: 1.6973e-05 - accuracy: 1.0000 - val_loss: 1.0278 - val_accuracy: 0.8800
# Epoch 989/1000
#  - 1s - loss: 1.7347e-05 - accuracy: 1.0000 - val_loss: 1.0280 - val_accuracy: 0.8800
# Epoch 990/1000
#  - 1s - loss: 1.7671e-05 - accuracy: 1.0000 - val_loss: 1.0285 - val_accuracy: 0.8800
# Epoch 991/1000
#  - 1s - loss: 1.4170e-05 - accuracy: 1.0000 - val_loss: 1.0290 - val_accuracy: 0.8800
# Epoch 992/1000
#  - 1s - loss: 1.5536e-05 - accuracy: 1.0000 - val_loss: 1.0294 - val_accuracy: 0.8800
# Epoch 993/1000
#  - 1s - loss: 1.6534e-05 - accuracy: 1.0000 - val_loss: 1.0298 - val_accuracy: 0.8800
# Epoch 994/1000
#  - 1s - loss: 2.3126e-05 - accuracy: 1.0000 - val_loss: 1.0301 - val_accuracy: 0.8800
# Epoch 995/1000
#  - 1s - loss: 1.6909e-05 - accuracy: 1.0000 - val_loss: 1.0305 - val_accuracy: 0.8800
# Epoch 996/1000
#  - 1s - loss: 3.2507e-05 - accuracy: 1.0000 - val_loss: 1.0315 - val_accuracy: 0.8800
# Epoch 997/1000
#  - 1s - loss: 1.4206e-05 - accuracy: 1.0000 - val_loss: 1.0325 - val_accuracy: 0.8800
# Epoch 998/1000
#  - 1s - loss: 1.4345e-05 - accuracy: 1.0000 - val_loss: 1.0335 - val_accuracy: 0.8800
# Epoch 999/1000
#  - 1s - loss: 2.0866e-05 - accuracy: 1.0000 - val_loss: 1.0348 - val_accuracy: 0.8800
# Epoch 1000/1000
#  - 1s - loss: 1.1879e-05 - accuracy: 1.0000 - val_loss: 1.0359 - val_accuracy: 0.8800
# Finished processing train dataset..
# Finished loading test dataset..
#
# Number of train samples :  100 Number of test samples :  100
# Number of classes :  2
# Sequence length :  147
# X_train.shape is  (100, 2, 147)
# X_test.shape is  (100, 2, 147)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-9889dbc5d552> in <module>
#       5 train_model(model, DATASET_INDEX, dataset_prefix=ds+'_', epochs=1000, batch_size=128)
#       6
# ----> 7 evaluate_model(model, DATASET_INDEX, dataset_prefix=ds+'_', batch_size=128)
#
# ~/PycharmProjects/SMATGAN/Baselines/MLTSM-FCN/MLSTM-FCN/utils/keras_utils.py in evaluate_model(model, dataset_id, dataset_prefix, dataset_fold_id, batch_size, test_data_subset, cutoff, normalize_timeseries)
#     193     else:
#     194         weight_fn = "./weights/%s_fold_%d_weights.h5" % (dataset_prefix, dataset_fold_id)
# --> 195     model.load_weights(weight_fn)
#     196
#     197     if test_data_subset is not None:
#
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1219         if h5py is None:
#    1220             raise ImportError('`load_weights` requires h5py.')
# -> 1221         with h5py.File(filepath, mode='r') as f:
#    1222             if 'layer_names' not in f.attrs and 'model_weights' in f:
#    1223                 f = f['model_weights']
#
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /opt/anaconda3/envs/python3_6/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = './weights/ECG__weights.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
